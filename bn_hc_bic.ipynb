# %% [markdown]
# ### Bayesian Network Structure Learnt with Bayesian Information Criterion

# %% [markdown]
# #### Prep training data

# %%
import bnlearn as bn
import pandas as pd
from sklearn.model_selection import train_test_split

# Load dataset and convert for trainning
rel_path = 'bn_train_cata_data.csv'
cata_data = pd.read_csv(rel_path)
dfhot, dfnum = bn.df2onehot(cata_data)
print(dfhot)
print(dfnum)

train_num, test_num = train_test_split(dfnum, test_size=0.2)

# prep eval data
index_ref_str_list = []
for i in test_num:
    index_ref_str_list.append(i)

test_info_dict_list = []
for i in test_num.index:
    curr_dict = {}
    for j in index_ref_str_list:
        curr_dict[j] = test_num[j][i]
    test_info_dict_list.append(curr_dict)
# Out:
# [df2onehot] >Auto detecting dtypes.
#   0%|          | 0/17 [00:00<?, ?it/s]
# 100%|██████████| 17/17 [00:00<00:00, 92.90it/s]
# [df2onehot] >Set dtypes in dataframe..
# [df2onehot]: 100%|██████████| 17/17 [00:00<00:00, 320.75it/s]
# [df2onehot] >Total onehot features: 48
#       flowS1-curr_large  flowS1-curr_medium  flowS1-curr_small  \
# 0                 False                True              False
# 1                 False                True              False
# 2                 False                True              False
# 3                 False                True              False
# 4                 False                True              False
# ...                 ...                 ...                ...
# 9054              False                True              False
# 9055              False                True              False
# 9056              False                True              False
# 9057              False                True              False
# 9058              False                True              False
#
#       prcpS1-1day_large  prcpS1-1day_medium  prcpS1-1day_small  \
# 0                  True               False              False
# 1                 False               False               True
# 2                 False               False               True
# 3                 False               False               True
# 4                  True               False              False
# ...                 ...                 ...                ...
# 9054              False               False               True
# 9055              False               False               True
# 9056              False               False               True
# 9057              False               False               True
# 9058              False               False               True
#
#       prcpS2-1day_large  prcpS2-1day_medium  prcpS2-1day_small  \
# 0                  True               False              False
# 1                 False                True              False
# 2                 False               False               True
# 3                 False               False               True
# 4                  True               False              False
# ...                 ...                 ...                ...
# 9054              False               False               True
# 9055              False               False               True
# 9056              False               False               True
# 9057              False               False               True
# 9058              False               False               True
#
#       prcpS3-1day_large  ...  prcpS2-3day_small  prcpS3-3day_large  \
# 0                  True  ...              False               True
# 1                  True  ...              False               True
# 2                 False  ...              False               True
# 3                 False  ...              False               True
# 4                  True  ...               True              False
# ...                 ...  ...                ...                ...
# 9054              False  ...               True              False
# 9055              False  ...               True              False
# 9056              False  ...               True              False
# 9057              False  ...               True              False
# 9058              False  ...               True              False
#
#       prcpS3-3day_medium  prcpS3-3day_small  flowS1-3day_large  \
# 0                  False              False              False
# 1                  False              False               True
# 2                  False              False               True
# 3                  False              False              False
# 4                  False               True              False
# ...                  ...                ...                ...
# 9054               False               True              False
# 9055               False               True              False
# 9056               False               True              False
# 9057               False               True              False
# 9058               False               True              False
#
#       flowS1-3day_medium  flowS1-3day_small  flowS2-3day_large  \
# 0                   True              False               True
# 1                  False              False               True
# 2                  False              False              False
# 3                   True              False              False
# 4                   True              False              False
# ...                  ...                ...                ...
# 9054                True              False              False
# 9055                True              False              False
# 9056                True              False              False
# 9057                True              False              False
# 9058                True              False              False
#
#       flowS2-3day_medium  flowS2-3day_small
# 0                  False              False
# 1                  False              False
# 2                   True              False
# 3                   True              False
# 4                   True              False
# ...                  ...                ...
# 9054                True              False
# 9055                True              False
# 9056                True              False
# 9057                True              False
# 9058                True              False
#
# [9059 rows x 48 columns]
#       flowS1-curr  prcpS1-1day  prcpS2-1day  prcpS3-1day  flowS1-1day  \
# 0               2            1            1            1            1
# 1               2            3            2            1            2
# 2               2            3            3            3            2
# 3               2            3            3            3            2
# 4               2            1            1            1            2
# ...           ...          ...          ...          ...          ...
# 9054            2            3            3            3            2
# 9055            2            3            3            3            2
# 9056            2            3            3            3            2
# 9057            2            3            3            3            2
# 9058            2            3            3            3            2
#
#       flowS2-1day  prcpS1-2day  prcpS2-2day  prcpS3-2day  flowS1-2day  \
# 0               2            1            1            1            1
# 1               2            1            1            1            1
# 2               2            3            2            1            2
# 3               2            3            3            3            2
# 4               2            3            3            3            2
# ...           ...          ...          ...          ...          ...
# 9054            2            3            3            3            2
# 9055            2            3            3            3            2
# 9056            2            3            3            3            2
# 9057            2            3            3            3            2
# 9058            2            3            3            3            2
#
#       flowS2-2day  prcpS1-3day  prcpS2-3day  prcpS3-3day  flowS1-3day  \
# 0               1            1            1            1            2
# 1               2            1            1            1            1
# 2               2            1            1            1            1
# 3               2            3            2            1            2
# 4               2            3            3            3            2
# ...           ...          ...          ...          ...          ...
# 9054            2            3            3            3            2
# 9055            2            3            3            3            2
# 9056            2            3            3            3            2
# 9057            2            3            3            3            2
# 9058            2            3            3            3            2
#
#       flowS2-3day
# 0               1
# 1               1
# 2               2
# 3               2
# 4               2
# ...           ...
# 9054            2
# 9055            2
# 9056            2
# 9057            2
# 9058            2
#
# [9059 rows x 16 columns]

# %% [markdown]
# #### Auto Structure Learning

# %%
model_hc_bic  = bn.structure_learning.fit(train_num, methodtype='hc', scoretype='bic')
G = bn.plot(model_hc_bic)
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model

# %% [markdown]
# #### Model Fit

# %%
# fit data into learnt structures 

model_bic = bn.parameter_learning.fit(model_hc_bic, dfnum)
# Out:
# [bnlearn] >Parameter learning> Computing parameters using [bayes]
# [bnlearn] >Converting [<class 'pgmpy.base.DAG.DAG'>] to BayesianNetwork model.
# [bnlearn] >Converting adjmat to BayesianNetwork.
# [bnlearn] >CPD of prcpS1-1day:
# +----------------+-----+---------------------+
# | flowS2-1day    | ... | flowS2-1day(3)      |
# +----------------+-----+---------------------+
# | prcpS1-2day    | ... | prcpS1-2day(3)      |
# +----------------+-----+---------------------+
# | prcpS1-1day(1) | ... | 0.09956828686068363 |
# +----------------+-----+---------------------+
# | prcpS1-1day(2) | ... | 0.0984712275890091  |
# +----------------+-----+---------------------+
# | prcpS1-1day(3) | ... | 0.8019604855503072  |
# +----------------+-----+---------------------+
# [bnlearn] >CPD of prcpS2-1day:
# +----------------+-----+----------------------+
# | prcpS1-1day    | ... | prcpS1-1day(3)       |
# +----------------+-----+----------------------+
# | prcpS3-1day    | ... | prcpS3-1day(3)       |
# +----------------+-----+----------------------+
# | prcpS2-1day(1) | ... | 0.018240884889068974 |
# +----------------+-----+----------------------+
# | prcpS2-1day(2) | ... | 0.03589885763437191  |
# +----------------+-----+----------------------+
# | prcpS2-1day(3) | ... | 0.9458602574765591   |
# +----------------+-----+----------------------+
# [bnlearn] >CPD of prcpS3-1day:
# +----------------+-----+----------------------+
# | prcpS1-1day    | ... | prcpS1-1day(3)       |
# +----------------+-----+----------------------+
# | prcpS3-2day    | ... | prcpS3-2day(3)       |
# +----------------+-----+----------------------+
# | prcpS3-1day(1) | ... | 0.01616641801738016  |
# +----------------+-----+----------------------+
# | prcpS3-1day(2) | ... | 0.052806365421734475 |
# +----------------+-----+----------------------+
# | prcpS3-1day(3) | ... | 0.9310272165608853   |
# +----------------+-----+----------------------+
# [bnlearn] >CPD of flowS1-curr:
# +----------------+-----+-----------------------+
# | flowS1-1day    | ... | flowS1-1day(3)        |
# +----------------+-----+-----------------------+
# | flowS1-3day    | ... | flowS1-3day(3)        |
# +----------------+-----+-----------------------+
# | prcpS3-1day    | ... | prcpS3-1day(3)        |
# +----------------+-----+-----------------------+
# | flowS1-curr(1) | ... | 0.0038186011700193983 |
# +----------------+-----+-----------------------+
# | flowS1-curr(2) | ... | 0.006911668117735111  |
# +----------------+-----+-----------------------+
# | flowS1-curr(3) | ... | 0.9892697307122454    |
# +----------------+-----+-----------------------+
# [bnlearn] >CPD of flowS1-1day:
# +----------------+-----+----------------------+
# | flowS1-2day    | ... | flowS1-2day(3)       |
# +----------------+-----+----------------------+
# | flowS2-1day    | ... | flowS2-1day(3)       |
# +----------------+-----+----------------------+
# | flowS1-1day(1) | ... | 0.008877173100769464 |
# +----------------+-----+----------------------+
# | flowS1-1day(2) | ... | 0.016194066008064185 |
# +----------------+-----+----------------------+
# | flowS1-1day(3) | ... | 0.9749287608911664   |
# +----------------+-----+----------------------+
# [bnlearn] >CPD of flowS2-1day:
# +----------------+-----+----------------------+
# | flowS2-2day    | ... | flowS2-2day(3)       |
# +----------------+-----+----------------------+
# | prcpS3-2day    | ... | prcpS3-2day(3)       |
# +----------------+-----+----------------------+
# | flowS2-1day(1) | ... | 0.010864275891251456 |
# +----------------+-----+----------------------+
# | flowS2-1day(2) | ... | 0.01857611340315244  |
# +----------------+-----+----------------------+
# | flowS2-1day(3) | ... | 0.9705596107055962   |
# +----------------+-----+----------------------+
# [bnlearn] >CPD of flowS1-2day:
# +----------------+-----+----------------------+
# | flowS2-1day    | ... | flowS2-1day(3)       |
# +----------------+-----+----------------------+
# | flowS2-2day    | ... | flowS2-2day(3)       |
# +----------------+-----+----------------------+
# | flowS1-2day(1) | ... | 0.010426715544408001 |
# +----------------+-----+----------------------+
# | flowS1-2day(2) | ... | 0.04537269277767059  |
# +----------------+-----+----------------------+
# | flowS1-2day(3) | ... | 0.9442005916779215   |
# +----------------+-----+----------------------+
# [bnlearn] >CPD of prcpS1-2day:
# +----------------+-----+----------------------+
# | prcpS2-2day    | ... | prcpS2-2day(3)       |
# +----------------+-----+----------------------+
# | prcpS3-2day    | ... | prcpS3-2day(3)       |
# +----------------+-----+----------------------+
# | prcpS1-2day(1) | ... | 0.013442522730019264 |
# +----------------+-----+----------------------+
# | prcpS1-2day(2) | ... | 0.041656892225231563 |
# +----------------+-----+----------------------+
# | prcpS1-2day(3) | ... | 0.9449005850447492   |
# +----------------+-----+----------------------+
# [bnlearn] >CPD of prcpS1-3day:
# +----------------+-----+---------------------+
# | prcpS1-2day    | ... | prcpS1-2day(3)      |
# +----------------+-----+---------------------+
# | prcpS3-2day    | ... | prcpS3-2day(3)      |
# +----------------+-----+---------------------+
# | prcpS1-3day(1) | ... | 0.09070464234116903 |
# +----------------+-----+---------------------+
# | prcpS1-3day(2) | ... | 0.11722213919194939 |
# +----------------+-----+---------------------+
# | prcpS1-3day(3) | ... | 0.7920732184668816  |
# +----------------+-----+---------------------+
# [bnlearn] >CPD of prcpS2-2day:
# +----------------+----------+
# | prcpS2-2day(1) | 0.253736 |
# +----------------+----------+
# | prcpS2-2day(2) | 0.127978 |
# +----------------+----------+
# | prcpS2-2day(3) | 0.618285 |
# +----------------+----------+
# [bnlearn] >CPD of prcpS3-2day:
# +----------------+-----+---------------------+
# | prcpS2-2day    | ... | prcpS2-2day(3)      |
# +----------------+-----+---------------------+
# | prcpS3-2day(1) | ... | 0.05693714939078857 |
# +----------------+-----+---------------------+
# | prcpS3-2day(2) | ... | 0.10533461964483509 |
# +----------------+-----+---------------------+
# | prcpS3-2day(3) | ... | 0.8377282309643763  |
# +----------------+-----+---------------------+
# [bnlearn] >CPD of flowS2-2day:
# +----------------+-----+---------------------+
# | prcpS3-2day    | ... | prcpS3-2day(3)      |
# +----------------+-----+---------------------+
# | prcpS3-3day    | ... | prcpS3-3day(3)      |
# +----------------+-----+---------------------+
# | flowS2-2day(1) | ... | 0.110262187804857   |
# +----------------+-----+---------------------+
# | flowS2-2day(2) | ... | 0.23286973487693488 |
# +----------------+-----+---------------------+
# | flowS2-2day(3) | ... | 0.6568680773182081  |
# +----------------+-----+---------------------+
# [bnlearn] >CPD of prcpS3-3day:
# +----------------+-----+----------------------+
# | prcpS1-3day    | ... | prcpS1-3day(3)       |
# +----------------+-----+----------------------+
# | prcpS3-2day    | ... | prcpS3-2day(3)       |
# +----------------+-----+----------------------+
# | prcpS3-3day(1) | ... | 0.015040556397803873 |
# +----------------+-----+----------------------+
# | prcpS3-3day(2) | ... | 0.05805517725758237  |
# +----------------+-----+----------------------+
# | prcpS3-3day(3) | ... | 0.9269042663446136   |
# +----------------+-----+----------------------+
# [bnlearn] >CPD of flowS1-3day:
# +----------------+-----+----------------------+
# | flowS1-2day    | ... | flowS1-2day(3)       |
# +----------------+-----+----------------------+
# | flowS2-2day    | ... | flowS2-2day(3)       |
# +----------------+-----+----------------------+
# | flowS1-3day(1) | ... | 0.008556792258294975 |
# +----------------+-----+----------------------+
# | flowS1-3day(2) | ... | 0.028722894696250112 |
# +----------------+-----+----------------------+
# | flowS1-3day(3) | ... | 0.9627203130454549   |
# +----------------+-----+----------------------+
# [bnlearn] >CPD of flowS2-3day:
# +----------------+-----+----------------------+
# | flowS1-3day    | ... | flowS1-3day(3)       |
# +----------------+-----+----------------------+
# | flowS2-2day    | ... | flowS2-2day(3)       |
# +----------------+-----+----------------------+
# | flowS2-3day(1) | ... | 0.008665055328104704 |
# +----------------+-----+----------------------+
# | flowS2-3day(2) | ... | 0.027088574294217266 |
# +----------------+-----+----------------------+
# | flowS2-3day(3) | ... | 0.964246370377678    |
# +----------------+-----+----------------------+
# [bnlearn] >CPD of prcpS2-3day:
# +----------------+-----+----------------------+
# | prcpS1-3day    | ... | prcpS1-3day(3)       |
# +----------------+-----+----------------------+
# | prcpS3-3day    | ... | prcpS3-3day(3)       |
# +----------------+-----+----------------------+
# | prcpS2-3day(1) | ... | 0.018297074322059882 |
# +----------------+-----+----------------------+
# | prcpS2-3day(2) | ... | 0.03581691516746172  |
# +----------------+-----+----------------------+
# | prcpS2-3day(3) | ... | 0.9458860105104784   |
# +----------------+-----+----------------------+
# [bnlearn] >Compute structure scores for model comparison (higher is better).

# %% [markdown]
# #### Testing Model with Test Data

# %%
curr_model = model_bic

model_correct_count = 0
for curr_dict in test_info_dict_list:
    curr_obs = curr_dict["flowS1-curr"] - 1 # result index is result cata -1
    print(curr_dict)
    curr_evidence_dict = curr_dict
    del curr_evidence_dict["flowS1-curr"]
    inf_result = bn.inference.fit(curr_model, variables=["flowS1-curr"], evidence=curr_evidence_dict)
    max_p_index = inf_result.df.idxmax().values[1] # this is the index of cata w/ highest p 
    curr_eval_result = max_p_index == curr_obs
    print(curr_obs)
    print(max_p_index)
    if max_p_index == curr_obs:
        model_correct_count += 1
        
model_bic_eval = model_correct_count/(len(test_info_dict_list))
print(model_bic_eval)
# Out:
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 1, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 1, 'prcpS2-2day': 3, 'prcpS3-2day': 2, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 1, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.249601  |
# +----+---------------+-----------+
# |  1 |             2 | 0.70078   |
# +----+---------------+-----------+
# |  2 |             3 | 0.0496191 |
# +----+---------------+-----------+
# 0
# 1
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 2, 'prcpS1-1day': 2, 'prcpS2-1day': 2, 'prcpS3-1day': 2, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 2, 'prcpS2-2day': 3, 'prcpS3-2day': 1, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 1, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+----------+
# |    |   flowS1-curr |        p |
# +====+===============+==========+
# |  0 |             1 | 0.22227  |
# +----+---------------+----------+
# |  1 |             2 | 0.624397 |
# +----+---------------+----------+
# |  2 |             3 | 0.153333 |
# +----+---------------+----------+
# 1
# 1
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 2, 'prcpS1-1day': 2, 'prcpS2-1day': 2, 'prcpS3-1day': 2, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 1, 'prcpS2-2day': 1, 'prcpS3-2day': 1, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 1, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.868058  |
# +----+---------------+-----------+
# |  1 |             2 | 0.0984879 |
# +----+---------------+-----------+
# |  2 |             3 | 0.0334538 |
# +----+---------------+-----------+
# 1
# 0
# {'flowS1-curr': 2, 'prcpS1-1day': 2, 'prcpS2-1day': 3, 'prcpS3-1day': 2, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 2, 'prcpS2-2day': 1, 'prcpS3-2day': 2, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0506    |
# +----+---------------+-----------+
# |  1 |             2 | 0.870939  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0784606 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 2, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 2
# 1
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 2, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 2, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0208177 |
# +----+---------------+-----------+
# |  1 |             2 | 0.0326214 |
# +----+---------------+-----------+
# |  2 |             3 | 0.946561  |
# +----+---------------+-----------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 2, 'prcpS2-1day': 3, 'prcpS3-1day': 1, 'flowS1-1day': 3, 'flowS2-1day': 2, 'prcpS1-2day': 1, 'prcpS2-2day': 1, 'prcpS3-2day': 1, 'flowS1-2day': 3, 'flowS2-2day': 2, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+----------+
# |    |   flowS1-curr |        p |
# +====+===============+==========+
# |  0 |             1 | 0.210851 |
# +----+---------------+----------+
# |  1 |             2 | 0.372528 |
# +----+---------------+----------+
# |  2 |             3 | 0.416621 |
# +----+---------------+----------+
# 2
# 2
# {'flowS1-curr': 1, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 2, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 1, 'prcpS2-2day': 1, 'prcpS3-2day': 1, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.868058  |
# +----+---------------+-----------+
# |  1 |             2 | 0.0984879 |
# +----+---------------+-----------+
# |  2 |             3 | 0.0334538 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 3, 'prcpS1-1day': 2, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 2, 'prcpS2-3day': 1, 'prcpS3-3day': 2, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0470465 |
# +----+---------------+-----------+
# |  1 |             2 | 0.131974  |
# +----+---------------+-----------+
# |  2 |             3 | 0.82098   |
# +----+---------------+-----------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 1, 'prcpS2-3day': 2, 'prcpS3-3day': 1, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 2, 'prcpS1-1day': 1, 'prcpS2-1day': 3, 'prcpS3-1day': 1, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 1, 'prcpS2-2day': 2, 'prcpS3-2day': 1, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 2, 'prcpS2-3day': 3, 'prcpS3-3day': 2, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.249601  |
# +----+---------------+-----------+
# |  1 |             2 | 0.70078   |
# +----+---------------+-----------+
# |  2 |             3 | 0.0496191 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 2, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 2, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 1, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.944886  |
# +----+---------------+-----------+
# |  1 |             2 | 0.039016  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0160978 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 3, 'prcpS1-1day': 2, 'prcpS2-1day': 2, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 2, 'prcpS2-2day': 2, 'prcpS3-2day': 2, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 2, 'prcpS2-2day': 2, 'prcpS3-2day': 2, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 2, 'prcpS2-3day': 2, 'prcpS3-3day': 2, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.850413  |
# +----+---------------+-----------+
# |  1 |             2 | 0.132027  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0175592 |
# +----+---------------+-----------+
# 1
# 0
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 1, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 1, 'prcpS2-2day': 1, 'prcpS3-2day': 1, 'flowS1-2day': 1, 'flowS2-2day': 2, 'prcpS1-3day': 2, 'prcpS2-3day': 2, 'prcpS3-3day': 2, 'flowS1-3day': 1, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.944886  |
# +----+---------------+-----------+
# |  1 |             2 | 0.039016  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0160978 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 2, 'prcpS2-3day': 2, 'prcpS3-3day': 1, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 3, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 2, 'prcpS2-3day': 2, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+----------+
# |    |   flowS1-curr |        p |
# +====+===============+==========+
# |  0 |             1 | 0.210851 |
# +----+---------------+----------+
# |  1 |             2 | 0.372528 |
# +----+---------------+----------+
# |  2 |             3 | 0.416621 |
# +----+---------------+----------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 2, 'prcpS2-1day': 3, 'prcpS3-1day': 2, 'flowS1-1day': 3, 'flowS2-1day': 2, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+----------+
# |    |   flowS1-curr |        p |
# +====+===============+==========+
# |  0 |             1 | 0.196153 |
# +----+---------------+----------+
# |  1 |             2 | 0.299038 |
# +----+---------------+----------+
# |  2 |             3 | 0.504809 |
# +----+---------------+----------+
# 2
# 2
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 1, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 1, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 2, 'prcpS2-2day': 3, 'prcpS3-2day': 2, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.850413  |
# +----+---------------+-----------+
# |  1 |             2 | 0.132027  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0175592 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 3, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0470465 |
# +----+---------------+-----------+
# |  1 |             2 | 0.131974  |
# +----+---------------+-----------+
# |  2 |             3 | 0.82098   |
# +----+---------------+-----------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 2, 'prcpS2-3day': 2, 'prcpS3-3day': 1, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 2, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 1, 'prcpS2-3day': 3, 'prcpS3-3day': 1, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0551055 |
# +----+---------------+-----------+
# |  1 |             2 | 0.0952775 |
# +----+---------------+-----------+
# |  2 |             3 | 0.849617  |
# +----+---------------+-----------+
# 2
# 2
# {'flowS1-curr': 2, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 1, 'prcpS2-2day': 1, 'prcpS3-2day': 1, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 2, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.249601  |
# +----+---------------+-----------+
# |  1 |             2 | 0.70078   |
# +----+---------------+-----------+
# |  2 |             3 | 0.0496191 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 1, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 2, 'prcpS2-2day': 2, 'prcpS3-2day': 2, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 2, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.850413  |
# +----+---------------+-----------+
# |  1 |             2 | 0.132027  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0175592 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 2, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 2, 'prcpS3-2day': 1, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 1, 'prcpS1-1day': 2, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 1, 'prcpS2-2day': 1, 'prcpS3-2day': 1, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.850413  |
# +----+---------------+-----------+
# |  1 |             2 | 0.132027  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0175592 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 3, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0470465 |
# +----+---------------+-----------+
# |  1 |             2 | 0.131974  |
# +----+---------------+-----------+
# |  2 |             3 | 0.82098   |
# +----+---------------+-----------+
# 2
# 2
# {'flowS1-curr': 2, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 2, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 1, 'prcpS2-3day': 2, 'prcpS3-3day': 2, 'flowS1-3day': 1, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+----------+
# |    |   flowS1-curr |        p |
# +====+===============+==========+
# |  0 |             1 | 0.22227  |
# +----+---------------+----------+
# |  1 |             2 | 0.624397 |
# +----+---------------+----------+
# |  2 |             3 | 0.153333 |
# +----+---------------+----------+
# 1
# 1
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 2, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 1, 'prcpS2-2day': 1, 'prcpS3-2day': 1, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0208177 |
# +----+---------------+-----------+
# |  1 |             2 | 0.0326214 |
# +----+---------------+-----------+
# |  2 |             3 | 0.946561  |
# +----+---------------+-----------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 2, 'prcpS2-2day': 2, 'prcpS3-2day': 2, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 1, 'prcpS1-1day': 2, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 3, 'prcpS2-2day': 2, 'prcpS3-2day': 3, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.944886  |
# +----+---------------+-----------+
# |  1 |             2 | 0.039016  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0160978 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 1, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 2, 'prcpS2-2day': 1, 'prcpS3-2day': 2, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 2, 'prcpS2-3day': 2, 'prcpS3-3day': 1, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.944886  |
# +----+---------------+-----------+
# |  1 |             2 | 0.039016  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0160978 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 1, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 1, 'prcpS2-2day': 2, 'prcpS3-2day': 2, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.249601  |
# +----+---------------+-----------+
# |  1 |             2 | 0.70078   |
# +----+---------------+-----------+
# |  2 |             3 | 0.0496191 |
# +----+---------------+-----------+
# 0
# 1
# {'flowS1-curr': 3, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 1, 'prcpS2-2day': 3, 'prcpS3-2day': 2, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 2, 'prcpS2-3day': 3, 'prcpS3-3day': 2, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0470465 |
# +----+---------------+-----------+
# |  1 |             2 | 0.131974  |
# +----+---------------+-----------+
# |  2 |             3 | 0.82098   |
# +----+---------------+-----------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 2, 'prcpS2-1day': 2, 'prcpS3-1day': 1, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 2, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0470465 |
# +----+---------------+-----------+
# |  1 |             2 | 0.131974  |
# +----+---------------+-----------+
# |  2 |             3 | 0.82098   |
# +----+---------------+-----------+
# 2
# 2
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 1, 'prcpS2-2day': 2, 'prcpS3-2day': 2, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 1, 'prcpS1-1day': 2, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 1, 'prcpS2-2day': 1, 'prcpS3-2day': 1, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.944886  |
# +----+---------------+-----------+
# |  1 |             2 | 0.039016  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0160978 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 2, 'prcpS2-1day': 2, 'prcpS3-1day': 2, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0208177 |
# +----+---------------+-----------+
# |  1 |             2 | 0.0326214 |
# +----+---------------+-----------+
# |  2 |             3 | 0.946561  |
# +----+---------------+-----------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 2, 'prcpS3-1day': 2, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0208177 |
# +----+---------------+-----------+
# |  1 |             2 | 0.0326214 |
# +----+---------------+-----------+
# |  2 |             3 | 0.946561  |
# +----+---------------+-----------+
# 2
# 2
# ...
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 2, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 2, 'prcpS2-2day': 3, 'prcpS3-2day': 2, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 1, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 1, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+----------+
# |    |   flowS1-curr |        p |
# +====+===============+==========+
# |  0 |             1 | 0.472169 |
# +----+---------------+----------+
# |  1 |             2 | 0.388867 |
# +----+---------------+----------+
# |  2 |             3 | 0.138964 |
# +----+---------------+----------+
# 0
# 0
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 1, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 3, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 2, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0208177 |
# +----+---------------+-----------+
# |  1 |             2 | 0.0326214 |
# +----+---------------+-----------+
# |  2 |             3 | 0.946561  |
# +----+---------------+-----------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 1, 'prcpS1-1day': 1, 'prcpS2-1day': 2, 'prcpS3-1day': 1, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 1, 'prcpS2-2day': 1, 'prcpS3-2day': 1, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.815788  |
# +----+---------------+-----------+
# |  1 |             2 | 0.125433  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0587786 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 3, 'prcpS1-2day': 2, 'prcpS2-2day': 3, 'prcpS3-2day': 2, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 2, 'prcpS2-3day': 1, 'prcpS3-3day': 2, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 1, 'prcpS1-1day': 2, 'prcpS2-1day': 3, 'prcpS3-1day': 2, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 1, 'prcpS2-2day': 1, 'prcpS3-2day': 1, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.868058  |
# +----+---------------+-----------+
# |  1 |             2 | 0.0984879 |
# +----+---------------+-----------+
# |  2 |             3 | 0.0334538 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 1, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 2, 'prcpS2-3day': 2, 'prcpS3-3day': 2, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.850413  |
# +----+---------------+-----------+
# |  1 |             2 | 0.132027  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0175592 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 3, 'prcpS1-1day': 1, 'prcpS2-1day': 2, 'prcpS3-1day': 1, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0470465 |
# +----+---------------+-----------+
# |  1 |             2 | 0.131974  |
# +----+---------------+-----------+
# |  2 |             3 | 0.82098   |
# +----+---------------+-----------+
# 2
# 2
# {'flowS1-curr': 2, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 2, 'flowS2-1day': 2, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 2, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 2, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0191934 |
# +----+---------------+-----------+
# |  1 |             2 | 0.901238  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0795686 |
# +----+---------------+-----------+
# 1
# 1
# {'flowS1-curr': 3, 'prcpS1-1day': 2, 'prcpS2-1day': 3, 'prcpS3-1day': 1, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0470465 |
# +----+---------------+-----------+
# |  1 |             2 | 0.131974  |
# +----+---------------+-----------+
# |  2 |             3 | 0.82098   |
# +----+---------------+-----------+
# 2
# 2
# {'flowS1-curr': 1, 'prcpS1-1day': 2, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 1, 'prcpS2-2day': 1, 'prcpS3-2day': 1, 'flowS1-2day': 1, 'flowS2-2day': 1, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 1, 'flowS2-3day': 1}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.944886  |
# +----+---------------+-----------+
# |  1 |             2 | 0.039016  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0160978 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 2, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 1, 'prcpS2-2day': 1, 'prcpS3-2day': 1, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 1, 'prcpS2-3day': 1, 'prcpS3-3day': 1, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0470465 |
# +----+---------------+-----------+
# |  1 |             2 | 0.131974  |
# +----+---------------+-----------+
# |  2 |             3 | 0.82098   |
# +----+---------------+-----------+
# 1
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 3, 'prcpS1-1day': 3, 'prcpS2-1day': 3, 'prcpS3-1day': 3, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 2, 'prcpS2-3day': 1, 'prcpS3-3day': 2, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+------------+
# |    |   flowS1-curr |          p |
# +====+===============+============+
# |  0 |             1 | 0.0038186  |
# +----+---------------+------------+
# |  1 |             2 | 0.00691167 |
# +----+---------------+------------+
# |  2 |             3 | 0.98927    |
# +----+---------------+------------+
# 2
# 2
# {'flowS1-curr': 1, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 1, 'flowS2-1day': 1, 'prcpS1-2day': 2, 'prcpS2-2day': 2, 'prcpS3-2day': 2, 'flowS1-2day': 1, 'flowS2-2day': 2, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 1, 'flowS2-3day': 2}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.944886  |
# +----+---------------+-----------+
# |  1 |             2 | 0.039016  |
# +----+---------------+-----------+
# |  2 |             3 | 0.0160978 |
# +----+---------------+-----------+
# 0
# 0
# {'flowS1-curr': 3, 'prcpS1-1day': 1, 'prcpS2-1day': 1, 'prcpS3-1day': 1, 'flowS1-1day': 3, 'flowS2-1day': 3, 'prcpS1-2day': 3, 'prcpS2-2day': 3, 'prcpS3-2day': 3, 'flowS1-2day': 3, 'flowS2-2day': 3, 'prcpS1-3day': 3, 'prcpS2-3day': 3, 'prcpS3-3day': 3, 'flowS1-3day': 3, 'flowS2-3day': 3}
# [bnlearn] >Variable Elimination.
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+---------------+-----------+
# |    |   flowS1-curr |         p |
# +====+===============+===========+
# |  0 |             1 | 0.0470465 |
# +----+---------------+-----------+
# |  1 |             2 | 0.131974  |
# +----+---------------+-----------+
# |  2 |             3 | 0.82098   |
# +----+---------------+-----------+
# 2
# 2
# 0.9293598233995585
